# %%
from ultralytics import YOLO

# %%
import torch
torch.__version__
# Out:
# '2.0.0'

# %%
model = YOLO("yolov8n.yaml")
model = YOLO("yolov8x.pt")
# Out:
# ...
# 100%|████████████████████████████████████████| 131M/131M [00:19<00:00, 7.15MB/s]

# %%
model.train(data="Volley_model.yaml", epochs=10)# train the model
# Out:
# New https://pypi.org/project/ultralytics/8.1.20 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.19 🚀 Python-3.9.16 torch-2.0.0 CPU (Apple M1 Pro)
# ...

# %%
metrics = model.val()
# Out:
# Ultralytics YOLOv8.1.19 🚀 Python-3.9.16 torch-2.0.0 CPU (Apple M1 Pro)
# Model summary (fused): 268 layers, 68124531 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /Users/infrered/Desktop/VolleyBall_Frames/VolleyBall_model/val/lab
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         63         63      0.896      0.587      0.655      0.246
# Speed: 0.4ms preprocess, 798.8ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to /Users/infrered/runs/detect/train192

# %%
model.save()
